# %%
import pandas as pd
from grading import *

# %% [markdown]
# # 문제 1-1

# %%
df_target = pd.read_csv("./datas/Summer-Olympic-medals-1976-to-2008.csv", encoding="ISO-8859-1")
df_target.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
df_target
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
check_01_01(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 20 / 100

# %% [markdown]
# # 문제 1-2

# %%
df_target.dropna(axis=0, inplace=True)
df_target
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
df_target.reset_index(drop=True, inplace=True)
df_target
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15311   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15312   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15313   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15314   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15315   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
check_01_02(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 20 / 100

# %% [markdown]
# # 문제 1-3

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15316 entries, 0 to 15315
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
for column in df_target.columns:
    if df_target[column].dtype == 'float64':
        df_target[column] = df_target[column].astype('int64')
    else:
        dtype = df_target[column].dtype

df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15316 entries, 0 to 15315
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  int64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.3+ MB

# %%
check_01_03(df_target)
# Out:
# 정답입니다! 10점 누적 되었습니다!
# 현재 누적 점수: 30 / 100

# %% [markdown]
# # 문제 2-1

# %%
df_target
# Out:
#            City  Year      Sport       Discipline           Event  \
# 0      Montreal  1976   Aquatics           Diving  3m springboard
# 1      Montreal  1976   Aquatics           Diving  3m springboard
# 2      Montreal  1976   Aquatics           Diving  3m springboard
# 3      Montreal  1976   Aquatics           Diving  3m springboard
# 4      Montreal  1976   Aquatics           Diving    10m platform
# ...         ...   ...        ...              ...             ...
# 15311   Beijing  2008  Wrestling  Wrestling Gre-R       66 - 74kg
# 15312   Beijing  2008  Wrestling  Wrestling Gre-R       66 - 74kg
# 15313   Beijing  2008  Wrestling  Wrestling Gre-R       55 - 60kg
# 15314   Beijing  2008  Wrestling  Wrestling Gre-R       60 - 66kg
# 15315   Beijing  2008  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
df_target['City'].unique()
# Out:
# array(['Montreal', 'Moscow', 'Los Angeles', 'Seoul', 'Barcelona',
#        'Atlanta', 'Sydney', 'Athens', 'Beijing'], dtype=object)

# %%
import copy
df_copy1 = copy.deepcopy(df_target)

# %%
df_archery = df_copy1[
    (df_copy1['Year']==2008)&
    (df_copy1['City']=='Beijing')&
    (df_copy1['Sport']=='Archery')&
    (df_copy1['Medal']=='Gold')&
    (df_copy1['Country_Code']=='KOR')
]
df_archery
# Out:
#           City  Year    Sport Discipline                            Event  \
# 13622  Beijing  2008  Archery    Archery  team (FITA Olympic round - 70m)
# 13636  Beijing  2008  Archery    Archery  team (FITA Olympic round - 70m)
# 13637  Beijing  2008  Archery    Archery  team (FITA Olympic round - 70m)
# 13639  Beijing  2008  Archery    Archery  team (FITA Olympic round - 70m)
# 13640  Beijing  2008  Archery    Archery  team (FITA Olympic round - 70m)
# 13644  Beijing  2008  Archery    Archery  team (FITA Olympic round - 70m)
#
#                Athlete Gender Country_Code       Country Event_gender Medal
# 13622      YUN, Ok-Hee  Women          KOR  Korea, South            W  Gold
# 13636   JOO, Hyun-Jung  Women          KOR  Korea, South            W  Gold
# 13637  LEE, Chang-Hwan    Men          KOR  Korea, South            M  Gold
# 13639    IM, Dong-Hyun    Men          KOR  Korea, South            M  Gold
# ...

# %%
check_02_01(df_archery)
# Out:
# 정답입니다! 15점 누적 되었습니다!
# 현재 누적 점수: 45 / 100

# %% [markdown]
# # 문제 2-2

# %%
df_copy2 = df_target[df_target['Country_Code'] == 'KOR'].copy()
df_copy2.head(2)
# Out:
#          City  Year Sport Discipline                 Event           Athlete  \
# 901  Montreal  1976  Judo       Judo         open category       CHO, Je-Aki
# 904  Montreal  1976  Judo       Judo  - 63kg (lightweight)  CHANG, Eun-Kyung
#
#     Gender Country_Code       Country Event_gender   Medal
# 901    Men          KOR  Korea, South            M  Bronze
# 904    Men          KOR  Korea, South            M  Silver

# %%
df_copy2 = df_copy2.drop_duplicates(subset=['City', 'Year', 'Sport', 'Discipline', 'Event', 'Country_Code', 'Country', 'Event_gender', 'Medal'])

# %%
df_kor = df_copy2.pivot_table(index=['Year', 'Medal'], values = 'City', aggfunc='count')
df_kor
# Out:
#              City
# Year Medal
# 1976 Bronze     4
#      Gold       1
#      Silver     1
# 1984 Bronze     7
#      Gold       6
#      Silver     6
# 1988 Bronze    11
#      Gold      12
#      Silver    10
# 1992 Bronze    11
#      Gold      12
#      Silver     5
# 1996 Bronze     5
#      Gold       7
#      Silver    15
# 2000 Bronze    10
#      Gold       8
#      Silver    10
# 2004 Bronze     9
#      Gold       9
#      Silver    12
# 2008 Bronze     8
#      Gold      13
#      Silver    10

# %%
df_kor = df_kor.reindex(['Gold', 'Silver', 'Bronze'], level=1)
df_kor
# Out:
#              City
# Year Medal
# 1976 Gold       1
#      Silver     1
#      Bronze     4
# 1984 Gold       6
#      Silver     6
#      Bronze     7
# 1988 Gold      12
#      Silver    10
#      Bronze    11
# 1992 Gold      12
#      Silver     5
#      Bronze    11
# 1996 Gold       7
#      Silver    15
#      Bronze     5
# 2000 Gold       8
#      Silver    10
#      Bronze    10
# 2004 Gold       9
#      Silver    12
#      Bronze     9
# 2008 Gold      13
#      Silver    10
#      Bronze     8

# %%
check_02_02(df_kor)
# Out:
# 정답입니다! 15점 누적 되었습니다!
# 현재 누적 점수: 60 / 100

# %% [markdown]
# # 문제 2-3

# %%
df_rank = df_target.copy()
df_rank = df_rank[df_rank['Year'] == 1996]
df_rank
# Out:
#          City  Year      Sport       Discipline                     Event  \
# 7402  Atlanta  1996   Aquatics           Diving            3m springboard
# 7403  Atlanta  1996   Aquatics           Diving            3m springboard
# 7404  Atlanta  1996   Aquatics           Diving              10m platform
# 7405  Atlanta  1996   Aquatics           Diving              10m platform
# 7406  Atlanta  1996   Aquatics           Diving            3m springboard
# ...       ...   ...        ...              ...                       ...
# 9256  Atlanta  1996  Wrestling  Wrestling Gre-R   62 - 68kg (lightweight)
# 9257  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9258  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9259  Atlanta  1996  Wrestling  Wrestling Gre-R     48 - 52kg (flyweight)
# 9260  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
#
#                         Athlete Gender Country_Code        Country  \
# ...

# %%
df_rank = df_rank.drop_duplicates(subset = ['City','Year', 'Sport', 'Discipline',
                                       'Event', 'Country_Code', 'Country',
                                       'Event_gender', 'Medal'])

# %%
df_rank
# Out:
#          City  Year      Sport       Discipline                     Event  \
# 7402  Atlanta  1996   Aquatics           Diving            3m springboard
# 7403  Atlanta  1996   Aquatics           Diving            3m springboard
# 7404  Atlanta  1996   Aquatics           Diving              10m platform
# 7405  Atlanta  1996   Aquatics           Diving              10m platform
# 7406  Atlanta  1996   Aquatics           Diving            3m springboard
# ...       ...   ...        ...              ...                       ...
# 9256  Atlanta  1996  Wrestling  Wrestling Gre-R   62 - 68kg (lightweight)
# 9257  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9258  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9259  Atlanta  1996  Wrestling  Wrestling Gre-R     48 - 52kg (flyweight)
# 9260  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
#
#                         Athlete Gender Country_Code        Country  \
# ...

# %%
df_rank_top10 = df_rank.groupby(['Country'])['Medal'].count()
df_rank_top10
# Out:
# Country
# Algeria             3
# Argentina           3
# Armenia             2
# Australia          41
# Austria             3
#                  ...
# United Kingdom     15
# United States     101
# Uzbekistan          2
# Yugoslavia          4
# Zambia              1
# Name: Medal, Length: 79, dtype: int64

# %%
df_rank_top10 = pd.DataFrame(df_rank_top10).reset_index()
df_rank_top10
# Out:
#            Country  Medal
# 0          Algeria      3
# 1        Argentina      3
# 2          Armenia      2
# 3        Australia     41
# 4          Austria      3
# ..             ...    ...
# 74  United Kingdom     15
# 75   United States    101
# 76      Uzbekistan      2
# 77      Yugoslavia      4
# 78          Zambia      1
#
# [79 rows x 2 columns]

# %%
df_rank_top10.sort_values('Medal', ascending=False, inplace=True)
df_rank_top10
# Out:
#           Country  Medal
# 75  United States    101
# 24        Germany     65
# 58         Russia     63
# 13          China     50
# 3       Australia     41
# ..            ...    ...
# 43         Mexico      1
# 32         Israel      1
# 26     Hong Kong*      1
# 28          India      1
# 78         Zambia      1
#
# [79 rows x 2 columns]

# %%
df_rank_top10 = df_rank_top10.head(10)

# %%
df_rank_top10
# Out:
#           Country  Medal
# 75  United States    101
# 24        Germany     65
# 58         Russia     63
# 13          China     50
# 3       Australia     41
# 22         France     37
# 33          Italy     35
# 39   Korea, South     27
# 16           Cuba     25
# 73        Ukraine     23

# %%
check_02_03(df_rank_top10)
# Out:
# 정답입니다! 20점 누적 되었습니다!
# 현재 누적 점수: 80 / 100

# %% [markdown]
# # 문제 2-4

# %%
df_rank
# Out:
#          City  Year      Sport       Discipline                     Event  \
# 7402  Atlanta  1996   Aquatics           Diving            3m springboard
# 7403  Atlanta  1996   Aquatics           Diving            3m springboard
# 7404  Atlanta  1996   Aquatics           Diving              10m platform
# 7405  Atlanta  1996   Aquatics           Diving              10m platform
# 7406  Atlanta  1996   Aquatics           Diving            3m springboard
# ...       ...   ...        ...              ...                       ...
# 9256  Atlanta  1996  Wrestling  Wrestling Gre-R   62 - 68kg (lightweight)
# 9257  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9258  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9259  Atlanta  1996  Wrestling  Wrestling Gre-R     48 - 52kg (flyweight)
# 9260  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
#
#                         Athlete Gender Country_Code        Country  \
# ...

# %%
df_rank2 = df_rank.copy()
df_rank2['Gold'] = (df_rank2['Medal'] == 'Gold').astype(int)
df_rank2['Silver'] = (df_rank2['Medal'] == 'Silver').astype(int)
df_rank2['Bronze'] = (df_rank2['Medal'] == 'Bronze').astype(int)
df_rank2
# Out:
#          City  Year      Sport       Discipline                     Event  \
# 7402  Atlanta  1996   Aquatics           Diving            3m springboard
# 7403  Atlanta  1996   Aquatics           Diving            3m springboard
# 7404  Atlanta  1996   Aquatics           Diving              10m platform
# 7405  Atlanta  1996   Aquatics           Diving              10m platform
# 7406  Atlanta  1996   Aquatics           Diving            3m springboard
# ...       ...   ...        ...              ...                       ...
# 9256  Atlanta  1996  Wrestling  Wrestling Gre-R   62 - 68kg (lightweight)
# 9257  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9258  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
# 9259  Atlanta  1996  Wrestling  Wrestling Gre-R     48 - 52kg (flyweight)
# 9260  Atlanta  1996  Wrestling  Wrestling Gre-R  68 - 74kg (welterweight)
#
#                         Athlete Gender Country_Code        Country  \
# ...

# %%
df_rank2 = df_rank2.pivot_table(index = 'Country', values = ['Gold', 'Silver', 'Bronze'], aggfunc='sum')
df_rank2.reset_index(inplace=True)
df_rank2
# Out:
#            Country  Bronze  Gold  Silver
# 0          Algeria       1     2       0
# 1        Argentina       1     0       2
# 2          Armenia       0     1       1
# 3        Australia      23     9       9
# 4          Austria       2     0       1
# ..             ...     ...   ...     ...
# 74  United Kingdom       6     1       8
# 75   United States      25    44      32
# 76      Uzbekistan       1     0       1
# 77      Yugoslavia       2     1       1
# 78          Zambia       0     0       1
#
# [79 rows x 4 columns]

# %%
df_rank2 = df_rank2[['Country', 'Gold', 'Silver', 'Bronze']]
df_rank2.sort_values(by=['Gold', 'Silver', 'Bronze'], ascending=False, inplace=True)
df_rank2 = df_rank2.head(10)
df_rank2
# Out:
#           Country  Gold  Silver  Bronze
# 75  United States    44      32      25
# 58         Russia    26      21      16
# 24        Germany    20      18      27
# 13          China    16      22      12
# 22         France    15       7      15
# 33          Italy    13      10      12
# 3       Australia     9       9      23
# 16           Cuba     9       8       8
# 73        Ukraine     9       2      12
# 39   Korea, South     7      15       5

# %%
check_02_04(df_rank2)
# Out:
# 정답입니다! 20점 누적 되었습니다!
# 현재 누적 점수: 100 / 100
